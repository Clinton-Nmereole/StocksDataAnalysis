# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

# %%
stocks_df = pd.read_csv("indexData.csv")
stocks_df
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  1965-12-31   528.690002   528.690002   528.690002   528.690002
# 1        NYA  1966-01-03   527.210022   527.210022   527.210022   527.210022
# 2        NYA  1966-01-04   527.840027   527.840027   527.840027   527.840027
# 3        NYA  1966-01-05   531.119995   531.119995   531.119995   531.119995
# 4        NYA  1966-01-06   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100  2021-05-27  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100  2021-05-28  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100  2021-05-31  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100  2021-06-01  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100  2021-06-02  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
stocks_df.describe()
# Out:
#                 Open           High            Low          Close  \
# count  110253.000000  110253.000000  110253.000000  110253.000000
# mean     7658.515222    7704.372961    7608.000422    7657.545872
# std      9011.478913    9066.638548    8954.506981    9011.510444
# min        54.869999      54.869999      54.869999      54.869999
# 25%      1855.030029    1864.510010    1843.979980    1855.060059
# 50%      5194.089844    5226.279785    5154.049805    5194.750000
# 75%     10134.299810   10207.820310   10060.349610   10134.830080
# max     68775.062500   69403.750000   68516.992190   68775.062500
#
#            Adj Close        Volume
# count  110253.000000  1.102530e+05
# mean     7657.351729  1.273975e+09
# std      9011.608900  4.315783e+09
# min        54.869999  0.000000e+00
# 25%      1854.179565  0.000000e+00
# 50%      5194.750000  4.329000e+05
# 75%     10134.830080  1.734314e+08
# max     68775.062500  9.440374e+10

# %% [markdown]
# We can create a new column year, by initiallly converting the datatype of stocks_df.Date from object to datetime using the inbuilt pandas function to_datetime. The DatetimeIndex function is then subsequently used to filter just the year from the Date and used to create a new column which we call year.

# %%
stocks_df.Date
# Out:
# 0         1965-12-31
# 1         1966-01-03
# 2         1966-01-04
# 3         1966-01-05
# 4         1966-01-06
#              ...
# 112452    2021-05-27
# 112453    2021-05-28
# 112454    2021-05-31
# 112455    2021-06-01
# 112456    2021-06-02
# Name: Date, Length: 112457, dtype: object

# %%
stocks_df['Date'] = pd.to_datetime(stocks_df['Date'])
stocks_df.Date
# Out:
# 0        1965-12-31
# 1        1966-01-03
# 2        1966-01-04
# 3        1966-01-05
# 4        1966-01-06
#             ...
# 112452   2021-05-27
# 112453   2021-05-28
# 112454   2021-05-31
# 112455   2021-06-01
# 112456   2021-06-02
# Name: Date, Length: 112457, dtype: datetime64[ns]

# %%
stocks_df["year"] = pd.DatetimeIndex(stocks_df.Date).year
stocks_df.year
# Out:
# 0         1965
# 1         1966
# 2         1966
# 3         1966
# 4         1966
#           ...
# 112452    2021
# 112453    2021
# 112454    2021
# 112455    2021
# 112456    2021
# Name: year, Length: 112457, dtype: int64

# %% [raw]
# Here, we can check the days with the greatest Highs. We can see that these days all happened in the year 2021 between the months March and May. We can also see that the index J203.JO was the Index that produced the greatest Highs exclusively.

# %%
stocks_df.sort_values(by='High', ascending=False).head(15)
# Out:
#          Index       Date         Open         High          Low        Close  \
# 92390  J203.JO 2021-03-03  68510.75000  69403.75000  68226.70313  68326.78906
# 92434  J203.JO 2021-05-10  68519.53125  69043.10156  68373.64063  68377.22656
# 92394  J203.JO 2021-03-09  68426.17188  69021.59375  68051.92188  68655.96094
# 92396  J203.JO 2021-03-11  68516.99219  68924.99219  68516.99219  68775.06250
# 92420  J203.JO 2021-04-19  68698.78125  68802.68750  68094.28125  68094.28125
# 92397  J203.JO 2021-03-12  68775.06250  68775.06250  67675.59375  68209.85938
# 92419  J203.JO 2021-04-16  67823.09375  68741.82813  67823.09375  68698.78125
# 92433  J203.JO 2021-05-07  67608.89063  68664.35938  67608.89063  68519.53125
# 92395  J203.JO 2021-03-10  68655.96094  68655.96094  67941.45313  68516.99219
# 92389  J203.JO 2021-03-02  67536.96094  68543.89844  67277.74219  68510.75000
# 92393  J203.JO 2021-03-08  68271.18750  68493.72656  67922.85938  68426.17188
# ...

# %%
plt.bar(stocks_df.year, stocks_df.High)
# Out:
# <BarContainer object of 112457 artists>

# %% [markdown]
# We can use a scatter plot to check the Index performance over the years. To do this, we can simply use the scatterplot function from the seaborn library. The x-axis is the year, the y-axis is the High and for the hue we use the Indexes.

# %%
sns.scatterplot(x=stocks_df.year, y=stocks_df.High, hue=stocks_df.Index)
# Out:
# <AxesSubplot:xlabel='year', ylabel='High'>
# /home/codesensei2001/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
stocks_df['Daychange'] = stocks_df.Close - stocks_df.Open 
stocks_df
# Out:
#        Index       Date         Open         High          Low        Close  \
# 0        NYA 1965-12-31   528.690002   528.690002   528.690002   528.690002
# 1        NYA 1966-01-03   527.210022   527.210022   527.210022   527.210022
# 2        NYA 1966-01-04   527.840027   527.840027   527.840027   527.840027
# 3        NYA 1966-01-05   531.119995   531.119995   531.119995   531.119995
# 4        NYA 1966-01-06   532.070007   532.070007   532.070007   532.070007
# ...      ...        ...          ...          ...          ...          ...
# 112452  N100 2021-05-27  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100 2021-05-28  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100 2021-05-31  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100 2021-06-01  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100 2021-06-02  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume  year  Daychange
# ...

# %%
stocks_df['Percent_change'] = (stocks_df.Daychange/ stocks_df.Open) * 100
stocks_df
# Out:
#        Index       Date         Open         High          Low        Close  \
# 0        NYA 1965-12-31   528.690002   528.690002   528.690002   528.690002
# 1        NYA 1966-01-03   527.210022   527.210022   527.210022   527.210022
# 2        NYA 1966-01-04   527.840027   527.840027   527.840027   527.840027
# 3        NYA 1966-01-05   531.119995   531.119995   531.119995   531.119995
# 4        NYA 1966-01-06   532.070007   532.070007   532.070007   532.070007
# ...      ...        ...          ...          ...          ...          ...
# 112452  N100 2021-05-27  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100 2021-05-28  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100 2021-05-31  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100 2021-06-01  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100 2021-06-02  1258.489990  1263.709961  1258.239990  1263.619995
#
# ...

# %%
stocks_df.sort_values(by='Percent_change', ascending=False).head(20)
# Out:
#             Index       Date          Open          High           Low  \
# 58459        NSEI 2009-05-18   3673.149902   4384.299805   3673.149902
# 21505        IXIC 2001-01-03   2254.560059   2618.030029   2251.709961
# 99165        N225 1990-10-02  20221.859380  22899.400390  20221.859380
# 32278         HSI 2008-10-28  11154.570310  12596.290040  11133.940430
# 103841       N225 2008-10-14   8407.940430   9455.620117   8407.940430
# 10769         NYA 2008-10-13   5704.129883   6413.149902   5704.129883
# 66852       GDAXI 2008-10-28   4314.910156   4823.450195   4314.910156
# 10780         NYA 2008-10-28   5196.540039   5735.970215   5178.160156
# 21325        IXIC 2000-04-17   3232.939941   3539.770020   3227.040039
# 61135        NSEI 2020-03-13   9107.599609  10159.400390   8555.150391
# 66871       GDAXI 2008-11-24   4167.709961   4579.069824   4154.549805
# 103853       N225 2008-10-30   8269.709961   9030.849609   8269.709961
# ...

# %%
stocks_df["month"] = pd.DatetimeIndex(stocks_df.Date).month
stocks_df.month
# Out:
# 0         12
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 112452     5
# 112453     5
# 112454     5
# 112455     6
# 112456     6
# Name: month, Length: 112457, dtype: int64

# %%
plt.bar(stocks_df.month, stocks_df.High)
# Out:
# <BarContainer object of 112457 artists>

# %%
sns.barplot(x=stocks_df.month, y=stocks_df.Percent_change)
# Out:
# <AxesSubplot:xlabel='month', ylabel='Percent_change'>

# %% [markdown]
# From the above graph, we can see that the months with the highest percent increase happened in November and December. This can possibly be attributed to the holidays Thanksgiving in November and Christmas in December. We can also see that the greatest drops happened in the Fall, between August and September.
